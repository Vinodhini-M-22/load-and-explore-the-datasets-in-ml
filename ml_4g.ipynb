# %%
import pandas as pd
csv_file_path='C:\ML_Project directory\\bca_project_titles.csv'
excel_file_path='C:\ML_Project directory\\job_roles.xlsx'

data_csv=pd.read_csv(csv_file_path)
print("csv file data:")
print(data_csv)

data_excel=pd.read_excel(excel_file_path)
print(data_excel)

print("Dataset information:")
print(data_csv.info())

print("\n First few rows of the dataset:")
print(data_csv.head())

print("\n Summary statistics:")
print(data_csv.describe())

print("\n Few Columns of the dataset:")
print(data_csv.info())

print("\n Few delete rows:")
print(data_csv.info())

print("\nDataset Shape (rows, columns):")
print(data_csv.shape)



print("\n Data Description:")
print("csv Data Description:")
print(data_csv.describe())

print("\n Excel Data Descriptions:")
print(data_excel.describe())

print("\n Data Types in csv file:")
print(data_csv.dtypes)


print("\n Data Types in Excel file:")
print(data_excel.dtypes)
# Out:
# csv file data:
#                                  Web-Based Projects:
# 0                 Online Bookstore Management System
# 1                            Event Management System
# 2                                  E-Learning Portal
# 3                   Blood Donation Management System
# 4                       Desktop/Mobile Applications:
# 5                          Library Management System
# 6                          Personalized Diet Planner
# 7                          Data/AI-Focused Projects:
# 8   Student Result Prediction Using Machine Learning
# 9             Sentiment Analysis for Product Reviews
# 10                         Database-Driven Projects:
# 11                        Hospital Management System
# 12                                 Online Job Portal
#             Job Role         Industry                         Description  \
# 0  Software Engineer    IT & Software     Develops and maintains software
# 1       Data Analyst        Analytics  Analyzes data to support decisions
# 2         HR Manager  Human Resources    Manages recruitment and policies
#
#   Qualification Experience Required
# 0    BCA/B.Tech             2 years
# 1       BCA/MCA              1 year
# 2           MBA             5 years
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Web-Based Projects:  13 non-null     object
# dtypes: object(1)
# memory usage: 236.0+ bytes
# None
#
#  First few rows of the dataset:
#                   Web-Based Projects:
# 0  Online Bookstore Management System
# 1             Event Management System
# 2                   E-Learning Portal
# 3    Blood Donation Management System
# 4        Desktop/Mobile Applications:
#
#  Summary statistics:
#                        Web-Based Projects:
# count                                   13
# unique                                  13
# top     Online Bookstore Management System
# freq                                     1
#
#  Few Columns of the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Web-Based Projects:  13 non-null     object
# dtypes: object(1)
# memory usage: 236.0+ bytes
# None
#
#  Few delete rows:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Web-Based Projects:  13 non-null     object
# dtypes: object(1)
# memory usage: 236.0+ bytes
# None
#
# Dataset Shape (rows, columns):
# (13, 1)
#
#  Data Description:
# csv Data Description:
#                        Web-Based Projects:
# count                                   13
# unique                                  13
# top     Online Bookstore Management System
# freq                                     1
#
#  Excel Data Descriptions:
#                  Job Role       Industry                      Description  \
# count                   3              3                                3
# unique                  3              3                                3
# top     Software Engineer  IT & Software  Develops and maintains software
# freq                    1              1                                1
#
#        Qualification Experience Required
# count              3                   3
# unique             3                   3
# top       BCA/B.Tech             2 years
# freq               1                   1
#
#  Data Types in csv file:
# Web-Based Projects:    object
# dtype: object
#
#  Data Types in Excel file:
# Job Role               object
# Industry               object
# Description            object
# Qualification          object
# Experience Required    object
# dtype: object
